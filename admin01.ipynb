# %%
<!DOCTYPE html>
<html lang="ko">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-4bw+/aepP/YC94hEpVNVgiZdgIC5+VKNBQNGCHeKRQN+PtmoHDEXuppvnDJzQIu9" crossorigin="anonymous">
  <title>KREAM - 크림</title>
  <style>
    /* 간단한 스타일 추가 */
    .hero-banner {
      background: url('https://via.placeholder.com/1920x600/FF6F61/FFFFFF?text=Welcome+to+KREAM') no-repeat center center;
      background-size: cover;
      height: 400px;
      color: white;
      display: flex;
      justify-content: center;
      align-items: center;
      text-align: center;
    }

    .hero-banner h1 {
      font-size: 4rem;
      font-weight: bold;
    }

    .product-card {
      border: 1px solid #ddd;
      border-radius: 10px;
      overflow: hidden;
    }

    .product-card img {
      width: 100%;
      height: 250px;
      object-fit: cover;
    }

    .product-card-body {
      padding: 15px;
    }

    .pagination {
      justify-content: center;
    }
  </style>
</head>
<body>

  <!-- 히어로 배너 -->
  <div class="hero-banner">
    <h1>패션과 문화의 중심, KREAM</h1>
  </div>

  <div class="container mt-5">
    <!-- 검색 바 -->
    <div class="row mb-4">
      <div class="col-12">
        <input type="text" class="form-control" id="search-input" placeholder="상품을 검색하세요..." />
      </div>
    </div>

    <!-- 최신 상품 -->
    <div class="mb-5">
      <h3>최신 상품</h3>
      <div class="row row-cols-1 row-cols-md-3 g-4">
        <!-- 상품 카드 예시 -->
        <div class="col">
          <div class="card product-card">
            <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
            <div class="product-card-body">
              <h5 class="card-title">슈프림 박스로고 후드티</h5>
              <p class="card-text">가격: 390,000원</p>
              <a href="#" class="btn btn-primary">자세히 보기</a>
            </div>
          </div>
        </div>
        <div class="col">
          <div class="card product-card">
            <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
            <div class="product-card-body">
              <h5 class="card-title">디젤 트랙 팬츠</h5>
              <p class="card-text">가격: 188,000원</p>
              <a href="#" class="btn btn-primary">자세히 보기</a>
            </div>
          </div>
        </div>
        <div class="col">
          <div class="card product-card">
            <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
            <div class="product-card-body">
              <h5 class="card-title">에어포스 1</h5>
              <p class="card-text">가격: 137,000원</p>
              <a href="#" class="btn btn-primary">자세히 보기</a>
            </div>
          </div>
        </div>
      </div>
    </div>

    <!-- 인기 상품 -->
    <div class="mb-5">
      <h3>인기 상품</h3>
      <div class="row row-cols-1 row-cols-md-3 g-4">
        <!-- 인기 상품 카드 예시 -->
        <div class="col">
          <div class="card product-card">
            <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
            <div class="product-card-body">
              <h5 class="card-title">에어맥스 97</h5>
              <p class="card-text">가격: 239,000원</p>
              <a href="#" class="btn btn-primary">자세히 보기</a>
            </div>
          </div>
        </div>
        <div class="col">
          <div class="card product-card">
            <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
            <div class="product-card-body">
              <h5 class="card-title">지갑 (Bottega Veneta)</h5>
              <p class="card-text">가격: 890,000원</p>
              <a href="#" class="btn btn-primary">자세히 보기</a>
            </div>
          </div>
        </div>
        <div class="col">
          <div class="card product-card">
            <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
            <div class="product-card-body">
              <h5 class="card-title">피지컬 리미티드 에디션</h5>
              <p class="card-text">가격: 550,000원</p>
              <a href="#" class="btn btn-primary">자세히 보기</a>
            </div>
          </div>
        </div>
      </div>
    </div>

    <!-- 페이지 네이션 -->
    <nav aria-label="Page navigation">
      <ul class="pagination">
        <li class="page-item disabled">
          <span class="page-link">이전</span>
        </li>
        <li class="page-item active">
          <span class="page-link">1</span>
        </li>
        <li class="page-item">
          <a class="page-link" href="#">2</a>
        </li>
        <li class="page-item">
          <a class="page-link" href="#">다음</a>
        </li>
      </ul>
    </nav>
  </div>

  <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/js/bootstrap.bundle.min.js"></script>
</body>
</html>

# %%
<!DOCTYPE html>
<html lang="ko">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>KREAM - 크림</title>
  <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-4bw+/aepP/YC94hEpVNVgiZdgIC5+VKNBQNGCHeKRQN+PtmoHDEXuppvnDJzQIu9" crossorigin="anonymous">
  <style>
    /* 히어로 배너 스타일 */
    .hero-banner {
      background: url('https://via.placeholder.com/1920x600/FF6F61/FFFFFF?text=Welcome+to+KREAM') no-repeat center center;
      background-size: cover;
      height: 400px;
      color: white;
      display: flex;
      justify-content: center;
      align-items: center;
      text-align: center;
    }
    .hero-banner h1 {
      font-size: 4rem;
      font-weight: bold;
    }
    .product-card img {
      height: 250px;
      object-fit: cover;
    }
    .product-card {
      border-radius: 10px;
      overflow: hidden;
    }
  </style>
</head>
<body>
  <!-- 헤더 -->
  <nav class="navbar navbar-expand-lg navbar-dark bg-dark">
    <div class="container-fluid">
      <a class="navbar-brand" href="#">KREAM</a>
      <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
        <span class="navbar-toggler-icon"></span>
      </button>
      <div class="collapse navbar-collapse" id="navbarNav">
        <ul class="navbar-nav ms-auto">
          <li class="nav-item">
            <a class="nav-link active" aria-current="page" href="#">홈</a>
          </li>
          <li class="nav-item">
            <a class="nav-link" href="#">카테고리</a>
          </li>
          <li class="nav-item">
            <a class="nav-link" href="#">내 계정</a>
          </li>
          <li class="nav-item">
            <a class="nav-link" href="#">로그인</a>
          </li>
        </ul>
      </div>
    </div>
  </nav>

  <!-- 히어로 배너 -->
  <div class="hero-banner">
    <h1>패션과 문화의 중심, KREAM</h1>
  </div>

  <!-- 검색 바 -->
  <div class="container mt-4">
    <div class="row">
      <div class="col-12">
        <input type="text" class="form-control" placeholder="상품을 검색하세요..." />
      </div>
    </div>
  </div>

  <!-- 최신 상품 섹션 -->
  <div class="container mt-5">
    <h3>최신 상품</h3>
    <div class="row row-cols-1 row-cols-md-3 g-4">
      <div class="col">
        <div class="card product-card">
          <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
          <div class="card-body">
            <h5 class="card-title">슈프림 박스로고 후드티</h5>
            <p class="card-text">가격: 390,000원</p>
            <a href="#" class="btn btn-primary">자세히 보기</a>
          </div>
        </div>
      </div>
      <div class="col">
        <div class="card product-card">
          <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
          <div class="card-body">
            <h5 class="card-title">디젤 트랙 팬츠</h5>
            <p class="card-text">가격: 188,000원</p>
            <a href="#" class="btn btn-primary">자세히 보기</a>
          </div>
        </div>
      </div>
      <div class="col">
        <div class="card product-card">
          <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
          <div class="card-body">
            <h5 class="card-title">에어포스 1</h5>
            <p class="card-text">가격: 137,000원</p>
            <a href="#" class="btn btn-primary">자세히 보기</a>
          </div>
        </div>
      </div>
    </div>
  </div>

  <!-- 인기 상품 섹션 -->
  <div class="container mt-5">
    <h3>인기 상품</h3>
    <div class="row row-cols-1 row-cols-md-3 g-4">
      <div class="col">
        <div class="card product-card">
          <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
          <div class="card-body">
            <h5 class="card-title">에어맥스 97</h5>
            <p class="card-text">가격: 239,000원</p>
            <a href="#" class="btn btn-primary">자세히 보기</a>
          </div>
        </div>
      </div>
      <div class="col">
        <div class="card product-card">
          <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
          <div class="card-body">
            <h5 class="card-title">지갑 (Bottega Veneta)</h5>
            <p class="card-text">가격: 890,000원</p>
            <a href="#" class="btn btn-primary">자세히 보기</a>
          </div>
        </div>
      </div>
      <div class="col">
        <div class="card product-card">
          <img src="https://via.placeholder.com/300x250" class="card-img-top" alt="상품 이미지">
          <div class="card-body">
            <h5 class="card-title">피지컬 리미티드 에디션</h5>
            <p class="card-text">가격: 550,000원</p>
            <a href="#" class="btn btn-primary">자세히 보기</a>
          </div>
        </div>
      </div>
    </div>
  </div>

  <!-- 페이지 네이션 -->
  <div class="container mt-4">
